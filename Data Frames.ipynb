# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Data Frames:

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
columns = ["Name","Age","City","Salary"]
df2 = pd.DataFrame(data_list,columns= columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# slecting coloumn from data frame

# %%
df2[['Name','City']]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [markdown]
# creating a new column

# %%
df2['designation'] = ['engineer', 'doctor', 'cricketer','buisnessman']
df2
# Out:
#     Name  Age      City  Salary  designation
# 0   John   28  New York   65000     engineer
# 1   Anna   34     Paris   70000       doctor
# 2  Peter   29    Berlin   62000    cricketer
# 3  Linda   42    London   85000  buisnessman

# %% [markdown]
# removing a column:

# %%
df2.drop('designation',axis = 1)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.drop(['Name',"Age"],axis = True)
# Out:
#        City  Salary  designation
# 0  New York   65000     engineer
# 1     Paris   70000       doctor
# 2    Berlin   62000    cricketer
# 3    London   85000  buisnessman

# %%
df2.drop(0,axis=0)
# Out:
#     Name  Age    City  Salary  designation
# 1   Anna   34   Paris   70000       doctor
# 2  Peter   29  Berlin   62000    cricketer
# 3  Linda   42  London   85000  buisnessman

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# Selecting column:

# %%
df2.loc[[0,2]]
# Out:
#     Name  Age      City  Salary designation
# 0   John   28  New York   65000    engineer
# 2  Peter   29    Berlin   62000   cricketer

# %% [markdown]
# selecting subset of raws & column

# %%
df2
# Out:
#     Name  Age      City  Salary  designation
# 0   John   28  New York   65000     engineer
# 1   Anna   34     Paris   70000       doctor
# 2  Peter   29    Berlin   62000    cricketer
# 3  Linda   42    London   85000  buisnessman

# %%
df2.loc[[0,2]][["Salary","designation"]]
# Out:
#    Salary designation
# 0   65000    engineer
# 2   62000   cricketer

# %% [markdown]
# conditional selection

# %%
df2
# Out:
#     Name  Age      City  Salary  designation
# 0   John   28  New York   65000     engineer
# 1   Anna   34     Paris   70000       doctor
# 2  Peter   29    Berlin   62000    cricketer
# 3  Linda   42    London   85000  buisnessman

# %%
# i only want to see those people whose age are above 30:
df2[df2['Age']>30]
# Out:
#     Name  Age    City  Salary  designation
# 1   Anna   34   Paris   70000       doctor
# 3  Linda   42  London   85000  buisnessman

# %%
# i only want data of those whose age is above 30 and salary bmust be above 75000:

df2[(df2['Age']>30) & (df2['Salary']>7500)]
# Out:
#     Name  Age    City  Salary  designation
# 1   Anna   34   Paris   70000       doctor
# 3  Linda   42  London   85000  buisnessman
