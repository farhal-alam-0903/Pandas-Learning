# %%
import pandas as pd
import numpy as np

# %% [markdown]
# CREATING SERIES:

# %%
labels = ['a', 'b', 'c']
my_list = [10, 20 , 30]
arr = np.arange(1,4)
my_dict = { 'name': 'farhal',
            'age ' : 19,
            'class' : 20


}

# %%
pd.Series(labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: str

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64
